# %%
import torch
from transformers import AutoTokenizer, AutoModelForSequenceClassification

# %%
tokenizer=AutoTokenizer.from_pretrained("final-model")
model=AutoModelForSequenceClassification.from_pretrained("final-model")
id2label=model.config.id2label

# %%
def predict_disease(text):
    print(f"\nOriginal user input: '{text}'")
    inputs = tokenizer(text, return_tensors="pt", truncation=True, padding=True, max_length=128).to(model.device)
    outputs = model(**inputs)
    probs = torch.softmax(outputs.logits, dim=-1).detach().cpu().numpy()[0]
    top3_idx = probs.argsort()[-3:][::-1]
    top3_diseases = [id2label[i] for i in top3_idx]
    top3_probs = [probs[i] for i in top3_idx]
    return list(zip(top3_diseases, top3_probs))

# %%
symptom_text = "Difficulty breathing, wheezing, chest tightness, and persistent cough especially at night"
print(predict_disease(symptom_text))
# Out:
# Original user input: 'Difficulty breathing, wheezing, chest tightness, and persistent cough especially at night'
# [('asthma', np.float32(0.3598367)), ('acute respiratory distress syndrome (ards)', np.float32(0.20570575)), ('acute bronchospasm', np.float32(0.16959901))]

# %%
import pandas as pd
df=pd.read_csv("final_symptoms_to_disease.csv")

# %%
df["diseases"].value_counts()
# Out:
# diseases
# cystitis                          1219
# vulvodynia                        1218
# nose disorder                     1218
# complex regional pain syndrome    1217
# spondylosis                       1216
#                                   ...
# fracture of the arm                437
# oppositional disorder              431
# hypovolemia                        424
# abdominal hernia                   407
# inguinal hernia                    402
# Name: count, Length: 254, dtype: int64

# %%
df["diseases"].unique()
# Out:
# array(['panic disorder', 'eye alignment disorder', 'vaginitis',
#        'glaucoma', 'eating disorder', 'transient ischemic attack',
#        'pyelonephritis', 'chronic pain disorder',
#        'problem during pregnancy', 'choledocholithiasis',
#        'diabetic retinopathy', 'fibromyalgia', 'acute pancreatitis',
#        'thrombophlebitis', 'asthma', 'teething syndrome',
#        'infectious gastroenteritis', 'acute sinusitis',
#        'postpartum depression', 'spondylitis', 'uterine fibroids',
#        'chalazion', 'vaginal yeast infection', 'ingrown toe nail',
#        'corneal disorder', 'viral warts', 'stroke',
#        'pelvic organ prolapse', 'fracture of the arm', 'hyperkalemia',
#        'cornea infection', 'chronic sinusitis', 'conductive hearing loss',
#        'abdominal hernia', 'marijuana abuse', 'indigestion', 'bursitis',
#        'pulmonary congestion', 'actinic keratosis', 'acute otitis media',
#        'chronic obstructive pulmonary disease (copd)', 'spondylosis',
#        'herpangina', 'injury to the shoulder', 'heart block',
#        'attention deficit hyperactivity disorder (adhd)',
#        'injury to the arm', 'complex regional pain syndrome',
#        'injury to the trunk', 'vulvodynia', 'concussion',
#        'bladder disorder', 'neuralgia', 'bipolar disorder',
#        'gastroesophageal reflux disease (gerd)', 'hypoglycemia',
#        'idiopathic absence of menstruation', 'hiatal hernia', 'allergy',
#        'chronic otitis media', 'lymphedema', 'acute bronchospasm',
#        'sciatica', 'degenerative disc disease', 'diverticulosis',
#        'pain after an operation', 'dermatitis due to sun exposure',
#        'fungal infection of the skin', 'injury to the leg',
#        'mitral valve disease', 'parkinson disease', 'gout',
#        'otitis media', 'drug abuse (opioids)', 'acute kidney injury',
#        'threatened pregnancy', 'gum disease',
#        'gastrointestinal hemorrhage', 'seborrheic dermatitis',
#        'food allergy', 'labyrinthitis', 'anxiety', 'bell palsy',
#        'conjunctivitis due to allergy', 'drug reaction', 'myopia',
#        'osteoarthritis', 'macular degeneration', 'pneumonia',
#        'fracture of the rib', 'vaginal cyst', 'alcohol abuse',
#        'carpal tunnel syndrome', 'kidney stone', 'autism',
#        'chronic glaucoma', 'nose disorder', 'dental caries',
#        'muscle spasm', 'itching of unknown cause', 'urge incontinence',
#        'corneal abrasion', 'dysthymic disorder',
#        'hypertensive heart disease', 'balanitis', 'alcohol withdrawal',
#        'hemiplegia', 'joint effusion', 'seasonal allergies (hay fever)',
#        'dry eye of unknown cause', 'fungal infection of the hair',
#        'tooth abscess', 'envenomation from spider or animal bite',
#        'rectal disorder', 'benign paroxysmal positional vertical (bppv)',
#        'stye', 'atrophic skin condition', 'oral mucosal lesion',
#        'intracerebral hemorrhage', 'ganglion cyst', 'skin disorder',
#        'tooth disorder', 'heart attack', 'fracture of the leg',
#        'oral thrush (yeast infection)', 'obstructive sleep apnea (osa)',
#        'hypokalemia', 'psoriasis', 'arthritis of the hip',
#        'sensorineural hearing loss', 'ileus', 'sickle cell crisis',
#        'urethritis', 'prostatitis', "otitis externa (swimmer's ear)",
#        'acute bronchiolitis', 'insect bite',
#        'paroxysmal ventricular tachycardia', 'pyogenic skin infection',
#        'viral exanthem', 'noninfectious gastroenteritis',
#        'benign prostatic hyperplasia (bph)', 'cataract',
#        'spinal stenosis', 'intestinal obstruction', 'acute bronchitis',
#        'ischemic heart disease', 'croup',
#        'idiopathic excessive menstruation', 'ear drum damage',
#        'erectile dysfunction', 'temporary or benign blood in urine',
#        'onychomycosis', 'iron deficiency anemia',
#        'acute respiratory distress syndrome (ards)', 'tendinitis',
#        'common cold', 'acne', 'depression', 'drug abuse',
#        'urinary tract obstruction', 'iridocyclitis',
#        'varicocele of the testicles', 'irritable bowel syndrome',
#        'ovarian cyst', 'lipoma', 'pulmonary hypertension',
#        'lymphadenitis', 'injury to the face', 'aortic valve disease',
#        'rheumatoid arthritis', 'impetigo', 'oppositional disorder',
#        'diabetic peripheral neuropathy',
#        'idiopathic irregular menstrual cycle',
#        'interstitial lung disease', 'mononeuritis', 'hypovolemia',
#        'schizophrenia', 'sepsis', 'cholecystitis', 'social phobia',
#        'ear wax impaction', 'rosacea', 'fracture of the facial bones',
#        'post-traumatic stress disorder (ptsd)', 'blepharitis', 'cystitis',
#        'hemorrhoids', 'contact dermatitis', 'sinus bradycardia',
#        'pelvic inflammatory disease', 'liver disease',
#        'chronic constipation', 'flu', 'skin polyp', 'brachial neuritis',
#        'esophagitis', 'yeast infection', 'diverticulitis',
#        'psychotic disorder', 'smoking or tobacco addiction',
#        'sprain or strain', 'idiopathic painful menstruation',
#        'eustachian tube dysfunction (ear disorder)', 'appendicitis',
#        'hyperemesis gravidarum', 'pleural effusion', 'sialoadenitis',
#        'urinary tract infection', 'ankylosing spondylitis',
#        'peripheral nerve disorder', 'sebaceous cyst', 'neurosis',
#        'seborrheic keratosis', 'spontaneous abortion',
#        'adjustment reaction', 'gallstone', 'multiple sclerosis', 'angina',
#        'skin pigmentation disorder', 'diabetic ketoacidosis',
#        'obsessive compulsive disorder (ocd)', 'hyponatremia',
#        'personality disorder', 'strep throat', 'gastritis', 'skin cancer',
#        'tonsillitis', 'developmental disability', 'acute stress reaction',
#        'delirium', 'callus', 'deviated nasal septum', 'hemangioma',
#        'chronic back pain', 'heart failure', 'conjunctivitis',
#        'herniated disk', 'breast infection (mastitis)',
#        'pulmonary embolism', 'conduct disorder', 'epididymitis',
#        'molluscum contagiosum', 'benign vaginal discharge (leukorrhea)',
#        'laryngitis', 'diaper rash', 'gastroduodenal ulcer',
#        'inguinal hernia', 'eczema', 'paronychia',
#        'white blood cell disease', 'spondylolisthesis',
#        'conjunctivitis due to virus'], dtype=object)

# %%
df[df["diseases"] == "heart attack"].nunique()
# Out:
# diseases          1
# symptom_text    810
# dtype: int64

# %%
from sklearn.utils import shuffle
df = shuffle(df).reset_index(drop=True)
df.head()
# Out:
#                                        diseases  \
# 0                                   diaper rash
# 1  chronic obstructive pulmonary disease (copd)
# 2                             brachial neuritis
# 3                           fracture of the leg
# 4                               marijuana abuse
#
#                                         symptom_text
# 0  irritable infant, vomiting, fever, temper prob...
# 1  shortness of breath, sharp chest pain, chest t...
# 2  headache, neck pain, low back pain, elbow pain...
# 3  hip pain, knee pain, knee swelling, leg stiffn...
# 4  anxiety and nervousness, depressive or psychot...

# %%
def predict_disease(text):
    print(f"\nOriginal user input: '{text}'")
    inputs = tokenizer(text, return_tensors="pt", truncation=True, padding=True, max_length=128).to(model.device)
    outputs = model(**inputs)
    probs = torch.softmax(outputs.logits, dim=-1).detach().cpu().numpy()[0]
    top3_idx = probs.argsort()[-3:][::-1]
    top3_diseases = [id2label[i] for i in top3_idx]
    top3_probs = [probs[i] for i in top3_idx]
    return list(zip(top3_diseases, top3_probs))

# %%
def run_test_cases():
	"""
	Run predictions for all test cases using predict_disease (defined in notebook),
	and calculate Top-1 and Top-3 accuracy.
	"""
	top1_correct = 0
	top3_correct = 0
	total = 100

	for i in range(1, total+1):
		symptoms=df["symptom_text"][i-1]  # Get symptoms from dataframe
		expected=df["diseases"][i-1]  # Get expected disease from dataframe
		try:
			preds = predict_disease(symptoms)  # returns list of (disease, prob)
			if not preds:
				print(f"❌ {i}. {expected}: no predictions")
				continue

			top1 = preds[0][0].lower()
			top3 = [p[0].lower() for p in preds]
			expected_lower = expected.lower()

			is_top1 = expected_lower in top1 or top1 in expected_lower
			is_top3 = any(expected_lower in d or d in expected_lower for d in top3)

			if is_top1:
				top1_correct += 1
				top3_correct += 1
				print(f"✅ {i}. {expected}: TOP-1 -> {preds[0][0]}")
			elif is_top3:
				top3_correct += 1
				print(f"⚠️  {i}. {expected}: in TOP-3 -> {top3}")
			else:
				print(f"❌ {i}. {expected}: TOP-1 -> {preds[0][0]} | TOP-3 -> {top3}")

		except Exception as e:
			print(f"❌ {i}. {expected}: Error -> {e}")

	top1_acc = (top1_correct / total) * 100 if total else 0.0
	top3_acc = (top3_correct / total) * 100 if total else 0.0

	print("\n" + "="*40)
	print(f"RESULTS: Total={total}")
	print(f"Top-1 Accuracy: {top1_acc:.2f}% ({top1_correct}/{total})")
	print(f"Top-3 Accuracy: {top3_acc:.2f}% ({top3_correct}/{total})")
	print("="*40)

	return top1_acc, top3_acc

# Run evaluation on the provided test_cases
run_test_cases()
# Out:
# Original user input: 'irritable infant, vomiting, fever, temper problems, skin rash, diaper rash'
# ✅ 1. diaper rash: TOP-1 -> diaper rash
#
# Original user input: 'shortness of breath, sharp chest pain, chest tightness, sore throat, nasal congestion, fever, congestion in chest'
# ✅ 2. chronic obstructive pulmonary disease (copd): TOP-1 -> chronic obstructive pulmonary disease (copd)
#
# Original user input: 'headache, neck pain, low back pain, elbow pain, paresthesia, shoulder pain'
# ✅ 3. brachial neuritis: TOP-1 -> brachial neuritis
#
# Original user input: 'hip pain, knee pain, knee swelling, leg stiffness or tightness'
# ✅ 4. fracture of the leg: TOP-1 -> fracture of the leg
#
# Original user input: 'anxiety and nervousness, depressive or psychotic symptoms, difficulty speaking, abusing alcohol, hostile behavior, delusions or hallucinations, fears and phobias'
# ✅ 5. marijuana abuse: TOP-1 -> marijuana abuse
#
# Original user input: 'diminished vision, double vision, symptoms of eye, pain in eye, abnormal movement of eyelid, foreign body sensation in eye, spots or clouds in vision'
# ✅ 6. diabetic retinopathy: TOP-1 -> diabetic retinopathy
#
# Original user input: 'abnormal involuntary movements, difficulty speaking, focal weakness, disturbance of memory, stiffness all over'
# ✅ 7. parkinson disease: TOP-1 -> parkinson disease
#
# Original user input: 'leg pain, neck pain, loss of sensation, lower body pain, back cramps or spasms'
# ✅ 8. chronic back pain: TOP-1 -> chronic back pain
#
# Original user input: 'hand or finger swelling, abnormal appearing skin, fluid retention, itching of skin'
# ⚠️  9. envenomation from spider or animal bite: in TOP-3 -> ['insect bite', 'envenomation from spider or animal bite', 'food allergy']
#
# Original user input: 'depressive or psychotic symptoms, insomnia, delusions or hallucinations, fears and phobias'
# ⚠️  10. psychotic disorder: in TOP-3 -> ['bipolar disorder', 'psychotic disorder', 'schizophrenia']
#
# Original user input: 'leg pain, hand or finger pain, knee pain, ankle pain, knee swelling, muscle pain, joint pain'
# ✅ 11. osteoarthritis: TOP-1 -> osteoarthritis
#
# Original user input: 'skin lesion, irregular appearing scalp, skin moles, joint pain'
# ✅ 12. psoriasis: TOP-1 -> psoriasis
#
# Original user input: 'suprapubic pain, sharp abdominal pain, vomiting, frequent urination, lower abdominal pain, blood in urine, low back pain'
# ⚠️  13. kidney stone: in TOP-3 -> ['pyelonephritis', 'kidney stone', 'pain after an operation']
#
# Original user input: 'vomiting, headache, nausea, pain during pregnancy, pelvic pain, problems during pregnancy, spotting or bleeding during pregnancy'
# ✅ 14. problem during pregnancy: TOP-1 -> problem during pregnancy
#
# Original user input: 'depression, depressive or psychotic symptoms, insomnia, abusing alcohol, hostile behavior, hysterical behavior'
# ✅ 15. psychotic disorder: TOP-1 -> psychotic disorder
#
# Original user input: 'pain in eye, lacrimation, itchiness of eye, swollen eye, eyelid swelling'
# ✅ 16. blepharitis: TOP-1 -> blepharitis
#
# Original user input: 'pelvic pain, cramps and spasms, blood clots during menstrual periods, unpredictable menstruation, painful menstruation'
# ✅ 17. idiopathic painful menstruation: TOP-1 -> idiopathic painful menstruation
#
# Original user input: 'depressive or psychotic symptoms, insomnia, weight gain'
# ✅ 18. eating disorder: TOP-1 -> eating disorder
#
# Original user input: 'abnormal appearing skin, skin dryness peeling scaliness or roughness'
# ❌ 19. hemangioma: TOP-1 -> acne | TOP-3 -> ['acne', 'dermatitis due to sun exposure', 'skin disorder']
#
# Original user input: 'depression, shortness of breath, depressive or psychotic symptoms'
# ⚠️  20. panic disorder: in TOP-3 -> ['anxiety', 'panic disorder', 'acute stress reaction']
#
# Original user input: 'cough, toothache, facial pain, tongue lesions, gum pain, mouth pain'
# ✅ 21. oral mucosal lesion: TOP-1 -> oral mucosal lesion
#
# Original user input: 'sharp chest pain, vomiting, burning abdominal pain, side pain, lower body pain, upper abdominal pain, stomach bloating, symptoms of the kidneys'
# ✅ 22. cholecystitis: TOP-1 -> cholecystitis
#
# Original user input: 'sharp abdominal pain, vomiting, diarrhea, lower abdominal pain, heartburn, rectal bleeding'
# ✅ 23. diverticulosis: TOP-1 -> diverticulosis
#
# Original user input: 'sharp chest pain, vomiting, nausea, back pain, burning abdominal pain, side pain, upper abdominal pain'
# ⚠️  24. acute pancreatitis: in TOP-3 -> ['cholecystitis', 'gallstone', 'acute pancreatitis']
#
# Original user input: 'cough, abnormal appearing skin, peripheral edema, itchiness of eye, allergic reaction'
# ✅ 25. allergy: TOP-1 -> allergy
#
# Original user input: 'cough, diminished vision, symptoms of eye, eye redness, lacrimation, itchiness of eye, eye burns or stings, allergic reaction'
# ✅ 26. conjunctivitis due to allergy: TOP-1 -> conjunctivitis due to allergy
#
# Original user input: 'hand or finger pain, back pain, loss of sensation, paresthesia, shoulder pain'
# ✅ 27. brachial neuritis: TOP-1 -> brachial neuritis
#
# Original user input: 'skin swelling, acne or pimples, skin growth, itching of skin, skin irritation, warts'
# ⚠️  28. seborrheic keratosis: in TOP-3 -> ['skin polyp', 'seborrheic keratosis', 'skin disorder']
#
# Original user input: 'sharp abdominal pain, vomiting, nausea, lower abdominal pain, vaginal discharge, pelvic pain, burning abdominal pain, painful menstruation'
# ✅ 29. ovarian cyst: TOP-1 -> ovarian cyst
#
# Original user input: 'dizziness, sore throat, nasal congestion, diminished hearing, ringing in ear, plugged feeling in ear, allergic reaction, abnormal breathing sounds, swollen or red tonsils'
# ✅ 30. eustachian tube dysfunction (ear disorder): TOP-1 -> eustachian tube dysfunction (ear disorder)
#
# Original user input: 'suprapubic pain, painful urination, burning abdominal pain'
# ✅ 31. benign vaginal discharge (leukorrhea): TOP-1 -> benign vaginal discharge (leukorrhea)
#
# Original user input: 'sharp abdominal pain, headache, lower abdominal pain, back pain, pain during pregnancy, pelvic pain, cramps and spasms'
# ✅ 32. problem during pregnancy: TOP-1 -> problem during pregnancy
#
# Original user input: 'sharp abdominal pain, nausea, lower abdominal pain, heartburn'
# ✅ 33. idiopathic absence of menstruation: TOP-1 -> idiopathic absence of menstruation
#
# Original user input: 'sore throat, vomiting, nausea, chills, coryza'
# ✅ 34. flu: TOP-1 -> flu
#
# Original user input: 'involuntary urination, pain during intercourse, symptoms of prostate, excessive urination at night'
# ✅ 35. erectile dysfunction: TOP-1 -> erectile dysfunction
#
# Original user input: 'dizziness, nausea, diarrhea, changes in stool appearance'
# ✅ 36. gastrointestinal hemorrhage: TOP-1 -> gastrointestinal hemorrhage
#
# Original user input: 'headache, back pain, neck pain, low back pain, elbow pain, paresthesia'
# ✅ 37. brachial neuritis: TOP-1 -> brachial neuritis
#
# Original user input: 'leg pain, arm pain, back pain, loss of sensation, paresthesia, shoulder pain'
# ✅ 38. degenerative disc disease: TOP-1 -> degenerative disc disease
#
# Original user input: 'chest tightness, cough, difficulty in swallowing, sharp abdominal pain, nausea, burning abdominal pain'
# ✅ 39. gastroesophageal reflux disease (gerd): TOP-1 -> gastroesophageal reflux disease (gerd)
#
# Original user input: 'hostile behavior, problems with movement, focal weakness, slurring words, disturbance of memory, delusions or hallucinations'
# ✅ 40. delirium: TOP-1 -> delirium
#
# Original user input: 'skin swelling, abnormal appearing skin, skin lesion, acne or pimples, irregular appearing scalp, skin irritation'
# ⚠️  41. skin polyp: in TOP-3 -> ['skin disorder', 'skin polyp', 'fungal infection of the hair']
#
# Original user input: 'hand or finger pain, hand or finger swelling, foot or toe pain, foot or toe swelling, hand or finger lump or mass, skin on leg or foot looks infected, sinus congestion'
# ✅ 42. paronychia: TOP-1 -> paronychia
#
# Original user input: 'dizziness, headache, nausea, facial pain, double vision, neck pain'
# ✅ 43. concussion: TOP-1 -> concussion
#
# Original user input: 'skin swelling, facial pain, restlessness, jaw swelling, skin irritation'
# ✅ 44. dental caries: TOP-1 -> dental caries
#
# Original user input: 'skin swelling, skin lesion, skin moles, itching of skin'
# ❌ 45. skin pigmentation disorder: TOP-1 -> contact dermatitis | TOP-3 -> ['contact dermatitis', 'skin disorder', 'seborrheic keratosis']
#
# Original user input: 'leg pain, hip pain, back pain, low back pain, loss of sensation, lower body pain, joint pain'
# ✅ 46. degenerative disc disease: TOP-1 -> degenerative disc disease
#
# Original user input: 'headache, back pain, loss of sensation, shoulder pain'
# ✅ 47. neuralgia: TOP-1 -> neuralgia
#
# Original user input: 'sore throat, cough, nasal congestion, ear pain, coryza, painful sinuses'
# ✅ 48. acute sinusitis: TOP-1 -> acute sinusitis
#
# Original user input: 'nausea, diarrhea, burning abdominal pain, fever, rectal bleeding, fluid retention'
# ✅ 49. noninfectious gastroenteritis: TOP-1 -> noninfectious gastroenteritis
#
# Original user input: 'cough, headache, wheezing, fever'
# ⚠️  50. interstitial lung disease: in TOP-3 -> ['common cold', 'acute bronchitis', 'interstitial lung disease']
#
# Original user input: 'skin growth, neck swelling, foot or toe swelling, swollen eye, irregular appearing nails, skin dryness peeling scaliness or roughness'
# ✅ 51. ingrown toe nail: TOP-1 -> ingrown toe nail
#
# Original user input: 'retention of urine, blood in stool, sharp abdominal pain, vomiting, pain of the anus, changes in stool appearance, rectal bleeding'
# ✅ 52. chronic constipation: TOP-1 -> chronic constipation
#
# Original user input: 'abnormal involuntary movements, difficulty speaking, weakness, stiffness all over'
# ✅ 53. parkinson disease: TOP-1 -> parkinson disease
#
# Original user input: 'wrist pain, wrist swelling, knee pain, ankle pain, elbow pain, knee swelling, ankle swelling'
# ✅ 54. joint effusion: TOP-1 -> joint effusion
#
# Original user input: 'sharp abdominal pain, diarrhea, burning abdominal pain, decreased appetite, rectal bleeding'
# ✅ 55. noninfectious gastroenteritis: TOP-1 -> noninfectious gastroenteritis
#
# Original user input: 'abnormal appearing skin, acne or pimples, irregular appearing scalp, itching of skin, skin dryness peeling scaliness or roughness, warts, skin rash'
# ✅ 56. skin pigmentation disorder: TOP-1 -> skin pigmentation disorder
#
# Original user input: 'abnormal involuntary movements, difficulty speaking, problems with movement, weakness, focal weakness, leg stiffness or tightness'
# ✅ 57. parkinson disease: TOP-1 -> parkinson disease
#
# Original user input: 'shortness of breath, sharp chest pain, chest tightness, palpitations, fainting, decreased heart rate'
# ✅ 58. sinus bradycardia: TOP-1 -> sinus bradycardia
#
# Original user input: 'vomiting, nausea, weakness, decreased appetite'
# ✅ 59. diabetic ketoacidosis: TOP-1 -> diabetic ketoacidosis
#
# Original user input: 'pain in eye, foreign body sensation in eye, eye redness, lacrimation, eye burns or stings, cloudy eye'
# ✅ 60. iridocyclitis: TOP-1 -> iridocyclitis
#
# Original user input: 'abnormal involuntary movements, difficulty speaking, headache, arm stiffness or tightness, slurring words, seizures'
# ✅ 61. hemiplegia: TOP-1 -> hemiplegia
#
# Original user input: 'hand or finger pain, knee weakness, elbow pain, knee swelling, muscle pain, joint pain'
# ✅ 62. osteoarthritis: TOP-1 -> osteoarthritis
#
# Original user input: 'sore throat, facial pain, ear pain, fever, congestion in chest, sinus congestion, painful sinuses'
# ✅ 63. chronic sinusitis: TOP-1 -> chronic sinusitis
#
# Original user input: 'hoarse voice, sore throat, cough, ear pain, fever'
# ✅ 64. laryngitis: TOP-1 -> laryngitis
#
# Original user input: 'skin swelling, irregular appearing scalp, joint pain, skin rash'
# ✅ 65. psoriasis: TOP-1 -> psoriasis
#
# Original user input: 'plugged feeling in ear, fluid in ear, pulling at ears'
# ⚠️  66. chronic otitis media: in TOP-3 -> ['ear wax impaction', 'ear drum damage', 'otitis media']
#
# Original user input: 'sore throat, cough, headache, frontal headache, sneezing'
# ✅ 67. seasonal allergies (hay fever): TOP-1 -> seasonal allergies (hay fever)
#
# Original user input: 'painful urination, involuntary urination, frequent urination, blood in urine, constipation'
# ✅ 68. urge incontinence: TOP-1 -> urge incontinence
#
# Original user input: 'toothache, fever, bleeding gums, pain in gums'
# ✅ 69. gum disease: TOP-1 -> gum disease
#
# Original user input: 'depression, shortness of breath, depressive or psychotic symptoms, dizziness, chest tightness, breathing fast'
# ✅ 70. panic disorder: TOP-1 -> panic disorder
#
# Original user input: 'hoarse voice, throat feels tight, difficulty in swallowing, ear pain, coryza'
# ✅ 71. laryngitis: TOP-1 -> laryngitis
#
# Original user input: 'sharp abdominal pain, intermenstrual bleeding, cramps and spasms, long menstrual periods, unpredictable menstruation, painful menstruation, frequent menstruation'
# ✅ 72. idiopathic irregular menstrual cycle: TOP-1 -> idiopathic irregular menstrual cycle
#
# Original user input: 'sharp chest pain, sharp abdominal pain, headache, diarrhea, regurgitation 1'
# ✅ 73. gastritis: TOP-1 -> gastritis
#
# Original user input: 'sharp abdominal pain, painful urination, lower abdominal pain, pelvic pain, symptoms of bladder'
# ✅ 74. cystitis: TOP-1 -> cystitis
#
# Original user input: 'retention of urine, sharp abdominal pain, painful urination, lower abdominal pain, back pain, regurgitation, regurgitation 1, symptoms of bladder'
# ✅ 75. temporary or benign blood in urine: TOP-1 -> temporary or benign blood in urine
#
# Original user input: 'sore throat, difficulty speaking, cough, throat feels tight, fever'
# ✅ 76. laryngitis: TOP-1 -> laryngitis
#
# Original user input: 'symptoms of the scrotum and testes, headache, shoulder pain, lower body pain, rib pain'
# ✅ 77. injury to the trunk: TOP-1 -> injury to the trunk
#
# Original user input: 'weakness, focal weakness, disturbance of memory, fatigue, leg weakness'
# ✅ 78. multiple sclerosis: TOP-1 -> multiple sclerosis
#
# Original user input: 'leg pain, headache, arm pain, low back pain, problems with movement, loss of sensation, shoulder pain'
# ✅ 79. spinal stenosis: TOP-1 -> spinal stenosis
#
# Original user input: 'hand or finger pain, arm pain, shoulder pain, hand or finger weakness'
# ✅ 80. mononeuritis: TOP-1 -> mononeuritis
#
# Original user input: 'nasal congestion, irritable infant, mouth ulcer, fever, skin rash'
# ✅ 81. oral thrush (yeast infection): TOP-1 -> oral thrush (yeast infection)
#
# Original user input: 'wrist swelling, ankle pain, knee swelling, foot or toe swelling, joint pain'
# ✅ 82. gout: TOP-1 -> gout
#
# Original user input: 'anxiety and nervousness, depression, insomnia, hostile behavior, delusions or hallucinations, nightmares'
# ✅ 83. adjustment reaction: TOP-1 -> adjustment reaction
#
# Original user input: 'depression, abusing alcohol, hostile behavior, delusions or hallucinations'
# ⚠️  84. depression: in TOP-3 -> ['post-traumatic stress disorder (ptsd)', 'depression', 'psychotic disorder']
#
# Original user input: 'suprapubic pain, vaginal itching, painful urination, burning abdominal pain, vaginal redness, problems during pregnancy'
# ✅ 85. benign vaginal discharge (leukorrhea): TOP-1 -> benign vaginal discharge (leukorrhea)
#
# Original user input: 'blood in stool, sharp abdominal pain, vomiting, nausea, lower abdominal pain, upper abdominal pain, melena'
# ✅ 86. diverticulosis: TOP-1 -> diverticulosis
#
# Original user input: 'leg pain, hand or finger pain, wrist pain, back pain, neck pain, knee pain, ankle pain, shoulder pain'
# ✅ 87. sprain or strain: TOP-1 -> sprain or strain
#
# Original user input: 'shortness of breath, insomnia, abnormal involuntary movements, difficulty in swallowing, mouth dryness, sleepiness'
# ✅ 88. obstructive sleep apnea (osa): TOP-1 -> obstructive sleep apnea (osa)
#
# Original user input: 'sharp chest pain, irregular heartbeat, peripheral edema, lymphedema'
# ✅ 89. aortic valve disease: TOP-1 -> aortic valve disease
#
# Original user input: 'sore throat, headache, difficulty breathing, allergic reaction, abnormal breathing sounds, painful sinuses, nosebleed'
# ✅ 90. deviated nasal septum: TOP-1 -> deviated nasal septum
#
# Original user input: 'headache, toothache, facial pain, mouth ulcer, peripheral edema, jaw swelling'
# ✅ 91. tooth disorder: TOP-1 -> tooth disorder
#
# Original user input: 'sharp abdominal pain, vaginal itching, painful urination, blood in urine, penis pain, penile discharge'
# ✅ 92. urethritis: TOP-1 -> urethritis
#
# Original user input: 'cough, suprapubic pain, vomiting, weakness, difficulty breathing, chills'
# ✅ 93. sepsis: TOP-1 -> sepsis
#
# Original user input: 'hip pain, arm pain, back pain, problems with movement, paresthesia, shoulder pain'
# ✅ 94. spinal stenosis: TOP-1 -> spinal stenosis
#
# Original user input: 'leg pain, arm pain, loss of sensation, disturbance of memory, paresthesia, leg weakness'
# ✅ 95. peripheral nerve disorder: TOP-1 -> peripheral nerve disorder
#
# Original user input: 'cough, skin swelling, vomiting, fever, pulling at ears, itching of skin, skin rash'
# ✅ 96. viral exanthem: TOP-1 -> viral exanthem
#
# Original user input: 'dizziness, abnormal involuntary movements, abusing alcohol, fainting, vomiting, seizures, antisocial behavior'
# ✅ 97. alcohol withdrawal: TOP-1 -> alcohol withdrawal
#
# Original user input: 'skin swelling, symptoms of eye, pain in eye, eye burns or stings, eyelid swelling, eyelid lesion or rash'
# ✅ 98. stye: TOP-1 -> stye
#
# Original user input: 'sharp chest pain, nausea, diarrhea, vomiting blood, burning abdominal pain, fever'
# ✅ 99. gastritis: TOP-1 -> gastritis
#
# Original user input: 'lower abdominal pain, back pain, pelvic pain, problems during pregnancy, spotting or bleeding during pregnancy'
# ✅ 100. problem during pregnancy: TOP-1 -> problem during pregnancy
#
# ========================================
# RESULTS: Total=100
# Top-1 Accuracy: 88.00% (88/100)
# Top-3 Accuracy: 98.00% (98/100)
# ========================================
# (88.0, 98.0)
